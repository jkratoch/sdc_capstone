# %%
import tensorflow

# %%
tensorflow.__version__
# Out:
# '1.3.0'

# %%
import cv2
import matplotlib.pyplot as plt
from tl_classifier import TLClassifier
# %matplotlib inline

# %%
classifier = TLClassifier('SITE', 'model/frozen_inference_graph.pb')

# %% [markdown]
# ### Select Image to Classify

# %%
img_name = 'examples/2.jpg'
img = cv2.imread(img_name)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
classifier.get_classification(img)
# Out:
# Green
# 2
