# %%
import cv2
import matplotlib.pyplot as plt
from tl_classifier import TLClassifier
# %matplotlib
# Out:
# /home/desi/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using matplotlib backend: TkAgg

# %%
LABEL_DICT = {1: 'GREEN',
              2: 'RED',
              3: 'YELLOW',
              4: 'UNKNOWN'}

# %%
classifier = TLClassifier('SITE')

# %% [markdown]
# ### Select Image to Classify

# %%
img_name = 'examples/24.jpg'
img = cv2.imread(img_name)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
label = classifier.get_classification(img)
LABEL_DICT[label]
# Out:
# 'YELLOW'
